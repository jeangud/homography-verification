# %% [markdown]
# # Translation Perturbation $\Delta x$

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy
from sympy import Derivative, Matrix, Symbol

f = Symbol("f")
xc = Symbol("x_c")
yc = Symbol("y_c")

# Original camera pose
phi = Symbol("phi")  # Roll
theta = Symbol("theta")  # Pitch
psi = Symbol("psi")  # Yaw
x = Symbol("x")
y = Symbol("y")
# Non-zero otherwise degenerate homography since camera center aligned with plane
z = Symbol("z", nonzero=True)

# Viewpoint delta
dphi = Symbol("\Delta\phi")  # Roll
dtheta = Symbol("\Delta\\theta")  # Pitch
dpsi = Symbol("\Delta\psi")  # Yaw
dx = Symbol("\Delta x")
dy = Symbol("\Delta y")
dz = Symbol("\Delta z")

# %% [markdown]
# ## Define homography matrix

# %%
H_inv = Matrix(
    [
        [1, -dx * xc / (f * z), dx * xc * yc / (f * z)],
        [0, -(dx * yc - f * z) / (f * z), dx * yc**2 / (f * z)],
        [0, -dx / (f * z), (dx * yc + f * z) / (f * z)],
    ]
)
H_inv
# Out:
# Matrix([
# [1,         -\Delta x*x_c/(f*z),     \Delta x*x_c*y_c/(f*z)],
# [0, (-\Delta x*y_c + f*z)/(f*z),      \Delta x*y_c**2/(f*z)],
# [0,             -\Delta x/(f*z), (\Delta x*y_c + f*z)/(f*z)]])

# %% [markdown]
# ## Apply projective transform

# %%
u = Symbol("u")
v = Symbol("v")

p0 = H_inv @ Matrix([u, v, 1])
p0 = p0 / p0[2]  # Normalize for non-homogeneous coordinates
p0 = sympy.simplify(p0)

u0 = p0[0]
v0 = p0[1]

# %%
u0
# Out:
# (\Delta x*v*x_c - \Delta x*x_c*y_c - f*u*z)/(\Delta x*v - \Delta x*y_c - f*z)

# %%
v0
# Out:
# (-\Delta x*y_c**2 + v*(\Delta x*y_c - f*z))/(\Delta x*v - \Delta x*y_c - f*z)

# %% [markdown]
# ## Compute gradient

# %%
du0_dK = Derivative(u0, dx, evaluate=True).simplify()
du0_dK = sympy.expand(du0_dK).simplify().factor()
du0_dK
# Out:
# f*z*(u - x_c)*(v - y_c)/(-\Delta x*v + \Delta x*y_c + f*z)**2

# %%
dv0_dK = Derivative(v0, dx, evaluate=True).simplify()
dv0_dK = sympy.expand(dv0_dK).simplify().factor()
dv0_dK
# Out:
# f*z*(v - y_c)**2/(-\Delta x*v + \Delta x*y_c + f*z)**2

# %% [markdown]
# ## Compute gradient derivative

# %%
Derivative(du0_dK, dx, evaluate=True).simplify()
# Out:
# 2*f*z*(u - x_c)*(v - y_c)**2/(-\Delta x*v + \Delta x*y_c + f*z)**3

# %%
Derivative(dv0_dK, dx, evaluate=True).simplify()
# Out:
# 2*f*z*(v - y_c)**3/(-\Delta x*v + \Delta x*y_c + f*z)**3

# %% [markdown]
# ## Plots

# %%
k_values = np.deg2rad(np.linspace(-100, 100, 1000))

u0_subs = u0.subs({f: 30, xc: 32, yc: 32, z: -10, u: 12, v: 6})
v0_subs = v0.subs({f: 30, xc: 32, yc: 32, z: -10, u: 12, v: 6})

u0_values = [u0_subs.subs({dx: val}).evalf() for val in k_values]
v0_values = [v0_subs.subs({dx: val}).evalf() for val in k_values]

u0_values = np.array(u0_values, dtype=float)
v0_values = np.array(v0_values, dtype=float)

plt.figure(figsize=(10, 5))
plt.plot(np.rad2deg(k_values), u0_values, label="u0")
plt.plot(np.rad2deg(k_values), v0_values, label="v0")
plt.xlabel(r"$\kappa$")
plt.legend()
plt.grid(True)
plt.show()
